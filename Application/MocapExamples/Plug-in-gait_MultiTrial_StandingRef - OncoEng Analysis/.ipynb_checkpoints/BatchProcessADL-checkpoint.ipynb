# %%
# !dir /d "Subjects"
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is F01D-7E05
#
#  Directory of C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects
#
# [.]                          [S007]
# [..]                         [S008]
# [.ipynb_checkpoints]         [S009]
# BatchProcessADL.ipynb        [S010]
# BatchProcessSubjects.ipynb   [S011]
# [Python Error Reports]       [S012]
# [S001]                       [S013]
# [S002]                       [S014]
# [S003]                       [S015]
# [S004]                       [SX - Template]
# [S005]
# [S006]
#                2 File(s)         86,502 bytes
#               20 Dir(s)  145,506,050,048 bytes free

# %%
# !dir /s /b "Main.any"
# Out:
# C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects\S001\S001_ADLSit_000\Main.any
# C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects\S001\S001_ADLStand_000\Main.any
# C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects\S001\S001_BND_002\Main.any
# C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects\S001\S001_BND_003\Main.any
# C:\Users\menmrk\Documents\AnyBody.8.0.x\AMMR4-Beta-OncoEng\Application\MocapExamples\Plug-in-gait_MultiTrial_StandingRef - OncoEng Analysis\Subjects\S001\S001_BND_003_SLM\Main.any
# ...

# %%
import fnmatch
filtered = fnmatch.filter("Main.any", '?StandingRef?')

# %%
from anypytools import AnyPyProcess

folderlist = ["Subjects"]
app = AnyPyProcess(num_processes = 2,timeout = 10800)
macrolist = [
    'load "main.any"',
    'operation Main.RunParameterIdentification',
    'run'
]

#app.start_macro(macrolist, folderlist, search_subdirs= "S001_BND_00[3-9].Main.any");
#app.start_macro(macrolist, folderlist, search_subdirs= "S002_BND_00[3-9].Main.any");
#app.start_macro(macrolist, folderlist, search_subdirs= "S007_StS_00[0-9].Main.any");
#app.start_macro(macrolist, folderlist, search_subdirs= "S007_StS_01[0-9].Main.any");
#app.start_macro(macrolist, folderlist, search_subdirs= "S007_SiS_00[0-9].Main.any");
#app.start_macro(macrolist, folderlist, search_subdirs= "S007_SiS_01[0-9].Main.any");
#app.start_macro(macrolist, folderlist, search_subdirs= "S001_LtR_01[3-3].Main.any");
#app.start_macro(macrolist, folderlist, search_subdirs= "S007_OUT_01[6-8].Main.any");
#app.start_macro(macrolist, folderlist, search_subdirs= "S007_WLK_01[0-9].Main.any");
#app.start_macro(macrolist, folderlist, search_subdirs= "S007_WLK_02[0-9].Main.any");
#app.start_macro(macrolist, folderlist, search_subdirs= "S007_WLK_02[0-9].Main.any");
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Exception in thread Thread-6 (_worker):
# Traceback (most recent call last):
#   File "C:\Users\menmrk\AppData\Roaming\Python\Python312\site-packages\anypytools\abcutils.py", line 858, in _worker
#     with NamedTemporaryFile(
#          ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\menmrk\AppData\Local\anaconda3\Lib\tempfile.py", line 582, in NamedTemporaryFile
#     file = _io.open(dir, mode, buffering=buffering,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\menmrk\AppData\Local\anaconda3\Lib\tempfile.py", line 579, in opener
#     fd, name = _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\menmrk\AppData\Local\anaconda3\Lib\tempfile.py", line 256, in _mkstemp_inner
#     fd = _os.open(file, flags, 0o600)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
